# %%
import os
from AugRobFab_SceneIntegration.mkv_parser import AzureKinectRecorder

root = globals()['_dh'][0]

# %%
recorder = AzureKinectRecorder(fn='test', config='./config/rec_config.json', align=True, dir=root)
recorder.run()
